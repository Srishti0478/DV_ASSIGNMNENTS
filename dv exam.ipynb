# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:/Users/SRISHTI AGARWAL/Desktop/diamonds.csv")
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
data.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %%
data.drop('Unnamed: 0',inplace=True, axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
data.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
#dropping dimensionless features
data=data.drop(data[data['x']==0].index)
data=data.drop(data[data['y']==0].index)
data=data.drop(data[data['z']==0].index)

# %%
data.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53920.000000  53920.000000  53920.000000  53920.000000  53920.000000
# mean       0.797698     61.749514     57.456834   3930.993231      5.731627
# std        0.473795      1.432331      2.234064   3987.280446      1.119423
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5323.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53920.000000  53920.000000
# mean       5.734887      3.540046
# std        1.140126      0.702530
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
data.shape
# Out:
# (53920, 10)

# %%
print(data.color.unique())
print(data.cut.unique())
print(data.clarity.unique())
# Out:
# ['E' 'I' 'J' 'H' 'F' 'G' 'D']
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']
# ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']

# %%
corr=data.corr()
plt.subplots(figsize=(5,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.catplot(x="carat",y="price",hue="cut", kind="bar",data=data)
plt.xlabel('Cut',size=50)
plt.ylabel('Price',size=50)
# Out:
# Text(50.60911458333332, 0.5, 'Price')

# %%
plt.boxplot(data['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27728cba910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27728cba130>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27728cba7c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x27728cbd610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27728cbd880>],
#  'means': []}

# %%
data.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
plt.boxplot(data['carat'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27728c76a30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27728c765e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27728c76850>],
#  'medians': [<matplotlib.lines.Line2D at 0x27728c73040>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27728c73f70>],
#  'means': []}

# %%
plt.scatter(data['carat'],data['color'])
plt.title("Carat VS Color")
# Out:
# Text(0.5, 1.0, 'Carat VS Color')

# %%
sns.pairplot(data[['carat','depth','table','price']])

# %%
sns.displot(data["price"])
plt.xlabel("quality")
# Out:
# Text(0.5, 9.444444444444438, 'quality')

# %%
rollmean=data['price'].rolling(12).mean()

# %%
plt.xlabel('price')
plt.ylabel('cut')
plt.plot(rollmean)
plt.plot(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# F:\pyyy\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1505         try:
# -> 1506             ret = self.converter.convert(x, self.units, self)
#    1507         except Exception as e:
#
# F:\pyyy\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      48         if unit is None:
# ---> 49             raise ValueError(
#      50                 'Missing category information for StrCategoryConverter; '
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9304\35540343.py in <module>
#       2 plt.ylabel('cut')
# ...

# %%
sns.lineplot(x=data['cut'],y=data['price'])
